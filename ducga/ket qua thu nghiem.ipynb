# %% [markdown]
# **KẾT QUẢ THỬ NGHIỆM CHÍNH (TRÊN BỘ DỮ LIỆU V3) ĐƯỢC ĐƯA VÀO BÁO CÁO**

# %%
# Code tải dữ liệu thử nghiệm
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="I8MkrNUVX8hh6X7kqmPp")
# project = rf.workspace("graduation-project-2023").project("plants-diseases-detection-and-classification")
# version = project.version(3)
# dataset = version.download("yolov8")

# %%
from google.colab import drive
import os

# Kết nối Google Drive
drive.mount('/content/drive')

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=320,
#             plots=True)

# Kết quả chạy với kích thước 224
model_path = '/content/drive/MyDrive/dataset/runs/detect/resize224_20epoch/weights/best.pt'


data_path = '/content/drive/MyDrive/dataset/data.yaml'


model = YOLO(model_path)


metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=320,
#             plots=True)

# Kết quả chạy với kích thước 320
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen2/resize320_20epoch/weights/best.pt'


data_path = '/content/drive/MyDrive/dataset/data.yaml'


model = YOLO(model_path)


metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=640,
#             plots=True)

# Kết quả chạy với kích thước 640 và data augmentation mặc định
model_path = '/content/drive/MyDrive/dataset/runs/detect/resize640_20epoch/weights/best.pt'


data_path = '/content/drive/MyDrive/dataset/data.yaml'


model = YOLO(model_path)


metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO

# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=1,
#             fliplr=0.5,
#             plots=True)

# Kết quả chạy với kích thước 640 sau khi thêm tùy chỉnh data augmentation
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen2/resize640_20epoch_aug/weights/best.pt'


data_path = '/content/drive/MyDrive/dataset/data.yaml'


model = YOLO(model_path)


metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=50,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=1,
#             fliplr=0.5,
#             plots=True)

# Kết quả chạy cuối cùng
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen/50epoch_fullparams-2/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)

# %% [markdown]
# CÁC THỬ NGHIỆM KHÁC TRÊN BỘ DỮ LIỆU v3

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.4,
#             hsv_v=0.3,
#             scale=0.3,
#             degrees=30.0,
#             mosaic=1,
#             fliplr=0.5,
#             plots=True)

# Ảnh kích thước 640 với Augmentaion thay đổi: hsv_s: 0.4, scale:0.3, degrees: 30
model_path = '/content/drive/MyDrive/dataset/runs/detect/augmentation/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=0.5,
#             fliplr=0.5,
#             plots=True)

# Ảnh kích thước 640 với Augmentaion tự thiết lập nhưng Mosaic bằng 0.5
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen2/resize640_20epoch_aug_mosaic0.5/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=20,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=0.5,
#             mixup=0.2,
#             fliplr=0.5,
#             plots=True)

# Ảnh kích thước 640 với Augmentaion tự thiết lập bố sung thêm Mix up bằng 0.2 chạy 20 epoch
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen/resize640_aug_mixup/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)
# Kết quả có vẻ cao hơn so với ko có Mix up nhưng lúc chạy 50 epoch thì kết quả lại kém hơn

# %%
from ultralytics import YOLO
# model=YOLO("yolov8l.pt")
# model.train(data="Plants-Diseases-Detection-and-Classification-3/data.yaml",
#             epochs=50,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=0.5,
#             mixup=0.2,
#             fliplr=0.5,
#             plots=True)

# Ảnh kích thước 640 với Augmentaion tự thiết lập bố sung thêm Mix up bằng 0.2 chạy 50 epoch
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen/50_epoch_mix_up-2/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)

# %% [markdown]
# CÁC THỬ NGHIỆM TRÊN BỘ DỮ LIỆU XÓA CLASS ÍT MẪU VÀ REBALANCE

# %%
# Code tải dữ liệu thử nghiệm
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="QKNDG0baj1Z271i4XsXP")
# project = rf.workspace("ducga1237-gmail-com").project("phat-hien-benh-la-1")
# version = project.version(2)
# dataset = version.download("yolov8")

# %%
from ultralytics import YOLO
# model.train(data="/content/phat-hien-benh-la-1-2/data.yaml",
#             epochs=20,
#             imgsz=320,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=1,
#             fliplr=0.5,
#             plots=True)

# Ảnh kích thước 320 với Augmentaion tự thiết lập chạy 50 epoch trên dữ liệu mới
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen/rz320_aug_new_dataset_50epoch/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset_new/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)

# %%
from ultralytics import YOLO
# model.train(data="/content/phat-hien-benh-la-1-2/data.yaml",
#             epochs=20,
#             imgsz=640,
#             hsv_h=0.015,
#             hsv_s=0.2,
#             hsv_v=0.3,
#             scale=0.5,
#             degrees=15.0,
#             mosaic=1,
#             fliplr=0.5,
#             plots=True)

# Ảnh kích thước 640 với Augmentaion tự thiết lập chạy 50 epoch trên dữ liệu mới
model_path = '/content/drive/MyDrive/KetQuaHuanLuyen/rz640_aug_new_dataset_50epoch/weights/best.pt'

data_path = '/content/drive/MyDrive/dataset_new/data.yaml'

model = YOLO(model_path)

metrics = model.val(data=data_path, plots=True)
