# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="I8MkrNUVX8hh6X7kqmPp")
project = rf.workspace("graduation-project-2023").project("plants-diseases-detection-and-classification")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 134.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Plants-Diseases-Detection-and-Classification-3 in yolov8:: 100%|██████████| 5044/5044 [00:01<00:00, 4505.07it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset
# Out:
# /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset

# %%
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.9/112.6 GB disk)

# %%
model=YOLO("yolov8l.pt")
model.train(data="data.yaml",epochs=50,imgsz=224,plots=True)#640
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from IPython.display import Image
image_path='/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/runs/detect/train/results.png'
Image(filename=image_path, width=600)

# %%
image_path = '/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/runs/detect/train/train_batch0.jpg'
Image(filename=image_path, width =600)

# %%
Image(filename='/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
# 1. Load mô hình từ file trọng số best.pt của bạn
model = YOLO("/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/runs/detect/train/weights/best.pt")

# 2. Chạy đánh giá trên tập Validation
metrics = model.val(
    data="/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/data.yaml"
)
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 113 layers, 43,628,967 parameters, 0 gradients, 164.9 GFLOPs
# val: Fast image access ✅ (ping: 2.1±3.6 ms, read: 23.5±15.7 MB/s, size: 75.8 KB)
# val: Scanning /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/valid/labels.cache... 250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 38.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 4.1it/s 3.9s
#                    all        250        884      0.532      0.548      0.571      0.409
#        Apple Scab Leaf          6         14      0.605      0.643      0.716      0.478
#             Apple leaf          9         23      0.776      0.783      0.863      0.578
#        Apple rust leaf         11         39      0.842      0.359       0.59      0.332
# ...

# %%
# 1. Load mô hình từ file trọng số best.pt của bạn
model = YOLO("/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/runs/detect/train/weights/best.pt")

# 2. Chạy predict với các tham số tương ứng
results = model.predict(
    source="/content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/test/images",
    conf=0.25,
    save=True
)
# Out:
# image 1/249 /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/test/images/022_jpg.rf.ee76d9fd39f0ecbdc7c92bfe576782a8.jpg: 192x224 1 Corn Gray leaf spot, 1 Corn rust leaf, 70.0ms
# image 2/249 /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/test/images/02b13cea19417b15cf3d6ff534aa7ea653ad783094a60_1260x1260_jpg.rf.6c89f74bbcdc3e5295cb16ec15337ec2.jpg: 192x224 1 Cherry leaf, 20.9ms
# image 3/249 /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/test/images/02b13cea19417b15cf3d6ff534aa7ea653ad783094a60_1260x1260_jpg.rf.d9c3f775b4b2300489e875cc09b70d51.jpg: 192x224 1 Cherry leaf, 30.1ms
# image 4/249 /content/drive/MyDrive/YOLO/PlantsDiseasesDetectionDataset/test/images/052609-20Hartman-20Crabapple-20scab-20single-20leaf-JPG_jpg.rf.e0a09811a7e799fbea63caca061f227b.jpg: 192x224 1 Apple Scab Leaf, 21.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict/*.jpg')[:20]:
      display(Image(filename=image_path, width=600))
      print("\n")
